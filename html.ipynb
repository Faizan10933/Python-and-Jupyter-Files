# %%
import requests
page=requests.get('https://tdbcollege.ac.in/')
print(page)
(page.content)
# Out:
# <Response [200]>
# ...

# %%
from bs4 import BeautifulSoup
s=BeautifulSoup(page.content,'html.parser')
#print(s.prettify)
#l=list(s.children)
L=s.find_all('p')[0]
print(L)
# Out:
# <p align="justify">nbsp;
#
#
#     Welcome to the gate of Triveni Devi Bhalotia College, Raniganj, an institution where excellence is tradition. This premier College founded in 1957, is located in the heartbeat of coalfield region under the University of Burdwan and is for those who shall be pioneers, for tho...</p>

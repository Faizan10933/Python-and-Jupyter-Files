# %%
from PIL import Image
img=Image.open('C:\\Users\\FAIZAN\\Desktop\\ProImage\\Pro.jpg')
w,h=img.size
print(w,h)
#img.show()
img1=img.rotate(90)
img1.save('C:\\Users\\FAIZAN\\Desktop\\ProImage\\pic1.jpg')
# Out:
# 400 250

# %%
area=(0,0,w//2,h//2)
img2=img.crop(area)
img2.save('C:\\Users\\FAIZAN\\Desktop\\ProImage\\pic2.jpg')

# %%
img3=img.resize((w//2,h//2))
img3.save('C:\\Users\\FAIZAN\\Desktop\\ProImage\\pic3.jpg')

# %%
print(img.histogram())

# %%
img4=img.transpose(Image.FLIP_LEFT_RIGHT)
img4.save('C:\\Users\\FAIZAN\\Desktop\\ProImage\\pic4.jpg')

# %%
print(img.mode)

# %%
print(img.TwoBitMap())

# %%
print(img.split)

# %%
r,g,b=img.getpixel((1,1))
print(r,g,b)

# %%
img5=img.thumbnail((200,200))
img5.show()
#img5.save('C:\\Users\\FAIZAN\\Desktop\\ProImage\\pic5.jpg')

# %%
import cv2
import os

# %%
v=cv2.VideoCapture('C:\\Users\\FAIZAN\\Desktop\\ProImage\\Vd.mp4')
if no os.path,exists('video:')
os.makedirs()
i=0
while(True):
    p,q=v.read()
    if p:
        name=path+str(i)+'.jpg'
        cv2.imwrite(name,q)
        i+=1
    else:
        break
        v.release()
        cv2.destroyAllWindows()

# %%
from skimage import data

# %%
from matplotlib import pyplot as plt
from skimage import data
import glob
from skimage.io import imread
from skimage.color import rgb2gray
from skimage.feature import blob_dog,blob_doh,blob_log
from math import sqrt

# %%
file=glob.glob(r"C:\\Users\\FAIZAN\\Desktop\\ProImage\\Ant.jpg")[0]
im=imread(file,as_gray=True)
#plt.imshow(im,cmap=cf.gray)
plt.imshow(im)
plt.show()

# %%
blog=blob_log(im,max_sigma=30,num_sigma=10,threshold=.1)
blog[:,2]=blog[:,2]*sqrt(2)
c=len(blog)
print(c)
# Out:
# 753

# %%
import matplotlib.pyplot as plt
x=[2015,2016,2017,2018]
y=[200,280,900,650]
plt.plot(x,y,marker='o')

# %%
import pandas as pd
data=[[551,'Time Management',3,20],[552,'App Development'1,11],[553,'Data Analysis',2,19],[554,'Marketing Strategies',2,37]]
df=pd.DataFrame(data,columns=['Wid','Title','Speakers','Invitees'])
print(df)
# Out:
#   File "<ipython-input-20-38e293cc00ae>", line 2
#     data=[[551,'Time Management',3,20],[552,'App Development'1,11],[553,'Data Analysis',2,19],[554,'Marketing Strategies',2,37]]
#                                                              ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
d={'Wid':[551,552,553,554],'Title':['Time Management','App Development','Data Analysis','Marketing Strategies'],
  'Speakers':[3,1,2,2],'Invitees':[20,11,19,37]}
df=pd.DataFrame(d)
df['Total']=df['Speakers']+df['Invitees']
df
# Out:
#    Wid                 Title  Speakers  Invitees  Total
# 0  551       Time Management         3        20     23
# 1  552       App Development         1        11     12
# 2  553         Data Analysis         2        19     21
# 3  554  Marketing Strategies         2        37     39

# %%
df=pd.read_csv('C:\\Users\\FAIZAN\Desktop\sales.csv')
df.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# ...

# %%
d={'city':['Rng','Asn','Rng','Dgp'],'School':['NJSS','DAV','SKS','ABC'],'Student':['Faizan','Harry','Hermoine','jenny']}
df=pd.DataFrame(d)
df
# Out:
#   city School   Student
# 0  Rng   NJSS    Faizan
# 1  Asn    DAV     Harry
# 2  Rng    SKS  Hermoine
# 3  Dgp    ABC     jenny

# %%
import pandas as pd
d={'City':['RNG','ASN','KOL','DGP'],'SCHOOL':['ABC','CGP','DAV','POP'],'Roll':[1,2,3,4]}
df=pd.DataFrame(d)
df
# Out:
#   City SCHOOL  Roll
# 0  RNG    ABC     1
# 1  ASN    CGP     2
# 2  KOL    DAV     3
# 3  DGP    POP     4

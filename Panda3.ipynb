# %%
import pandas as pd
import numpy as np
df=pd.read_csv('Country.csv')
df.head(10)
pd.crosstab(index=df.Country,columns=df.Gender,margins=True)
pd.crosstab(index=df.Country,columns=df.Handed,aggfunc=np.mean)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-9325c65bfe3c> in <module>
#       4 df.head(10)
#       5 pd.crosstab(index=df.Country,columns=df.Gender,margins=True)
# ----> 6 pd.crosstab(index=df.Country,columns=df.Handed,aggfunc=np.mean)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     474
#     475     if values is None and aggfunc is not None:
# --> 476         raise ValueError("aggfunc cannot be used without values.")
#     477
#     478     if values is not None and aggfunc is None:
#
# ValueError: aggfunc cannot be used without values.

# %%
df=pd.read_csv('C:\\Users\\FAIZAN\Desktop\sales.csv')
df.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# ...

# %%
df1=df.groupby(['Branch','Total'])
df1.first()
# Out:
#                    Invoice ID       City Customer type  Gender  \
# Branch Total
# A      12.6945    308-39-1707     Yangon        Normal  Female
#        16.1070    490-29-1201     Yangon        Normal  Female
#        16.2750    593-08-5916     Yangon        Normal  Female
#        19.1940    802-43-8934     Yangon        Normal    Male
#        19.2465    382-03-4532     Yangon        Member  Female
#        20.6850    756-49-0168     Yangon        Member    Male
#        22.3860    896-34-0956     Yangon        Normal    Male
#        25.2630    633-91-1052     Yangon        Normal  Female
#        26.2500    568-88-3448     Yangon        Normal    Male
#        26.5545    856-22-8149     Yangon        Normal  Female
#        26.7960    840-76-5966     Yangon        Member    Male
#        30.4080    421-95-9805     Yangon        Normal  Female
#        32.1405    318-12-0304     Yangon        Normal    Male
#        32.1510    307-04-2070     Yangon        Member  Female
# ...

# %%
df1=df.groupby('Branch').agg({'Total':'sum'})
print(df1)
# Out:
#               Total
# Branch
# A       106200.3705
# B       106197.6720
# C       110568.7065

# %%
import pandas as pd
df=pd.read_csv("mov.csv")
df
# Out:
#           1,The Nightmare Before Christmas,1993,3.9,4568
# 0                              2,The Mummy,1932,3.5,4388
# 1                   3,Orphans of the Storm,1921,3.2,9062
# 2                   4,The Object of Beauty,1991,2.8,6150
# 3                             5,Night Tide,1963,2.8,5126
# 4                    6,One Magic Christmas,1985,3.8,5333
# 5                       7,Muriel's Wedding,1994,3.5,6323
# 6                          8,Mother's Boys,1994,3.4,5733
# 7            9,Nosferatu: Original Version,1929,3.5,5651
# 8                          10,Nick of Time,1995,3.4,5333
# 9                       11,Broken Blossoms,1919,3.3,5367
# 10                            12,Big Night,1996,3.6,6561
# 11               13,The Birth of a Nation,1915,2.9,12118
# 12                 14,The Boys from Brazil,1978,3.6,7417
# 13                       15,Big Doll House,1971,2.9,5696
# 14                   16,The Breakfast Club,1985,4.0,5823
# ...

# %%
with open('movies_dataset.txt') as f:
    contents = f.read()
    print(contents)

# %%
import pandas as pd
df=pd.read_csv("mov.csv")
ages = df["1993"]
ages.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1993'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-0956db574bf0> in <module>
#       1 import pandas as pd
# ...
